# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
crypto_file_path ="data/crypto_data.csv"
crypto_df = pd.read_csv(crypto_file_path)
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
crypto_df.dtypes
# Out:
# Unnamed: 0          object
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
crypto_df.convert_dtypes().dtypes
# Out:
# Unnamed: 0          string
# CoinName            string
# Algorithm           string
# IsTrading          boolean
# ProofType           string
# TotalCoinsMined    Float64
# TotalCoinSupply     string
# dtype: object

# %%
crypto_df = crypto_df.loc[crypto_df["IsTrading"] == True]

crypto_df
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
crypto_df = crypto_df.drop(columns=['IsTrading'])
crypto_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
crypto_df = crypto_df.dropna()
crypto_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...

# %%
crypto_df = crypto_df.loc[crypto_df["TotalCoinsMined"] > 0]
crypto_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...

# %%
crypto_df = crypto_df.drop(columns=['CoinName', 'Unnamed: 0'])
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
crypto_df = crypto_df.reset_index(drop=True)
crypto_df
# Out:
#        Algorithm ProofType  TotalCoinsMined TotalCoinSupply  class
# 0         Scrypt   PoW/PoS     4.199995e+01              42      2
# 1         Scrypt   PoW/PoS     1.055185e+09       532000000      2
# 2            X13   PoW/PoS     2.927942e+10    314159265359      0
# 3        SHA-256       PoW     1.792718e+07        21000000      2
# 4         Ethash       PoW     1.076842e+08               0      0
# ..           ...       ...              ...             ...    ...
# 527      SHA-256      DPoS     2.000000e+09      2000000000      3
# 528       Scrypt   PoW/PoS     1.493105e+07       250000000      2
# 529  CryptoNight       PoW     9.802226e+08      1400222610      2
# 530     Equihash       PoW     7.296538e+06        21000000      3
# 531       Scrypt       PoS     1.283270e+05         1000000      0
#
# [532 rows x 5 columns]

# %%
crypto_learner_df = pd.get_dummies(crypto_df)
crypto_learner_df
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 0        4.199995e+01                                 0              0
# 2        1.055185e+09                                 0              0
# 5        2.927942e+10                                 0              0
# 7        1.792718e+07                                 0              0
# 8        1.076842e+08                                 0              0
# ...               ...                               ...            ...
# 1238     2.000000e+09                                 0              0
# 1242     1.493105e+07                                 0              0
# 1245     9.802226e+08                                 0              0
# 1246     7.296538e+06                                 0              0
# 1247     1.283270e+05                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
scaler = StandardScaler().fit(crypto_learner_df)
crypto_scaled = scaler.transform(crypto_learner_df)
crypto_scaled
# Out:
# array([[-0.11710817, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.90)

crypto_pca = pca.fit_transform(crypto_scaled)
crypto_pca.shape
# Out:
# (532, 274)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(learning_rate=200)
tsne_features = tsne.fit_transform(crypto_pca)

# %%
tsne_features.shape
# Out:
# (532, 2)

# %%
plt.scatter(tsne_features[:,0], tsne_features[:,1])
plt.show()

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(tsne_features)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
elbow_df = pd.DataFrame(elbow_data)
elbow_df
# Out:
# C:\Users\chris\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
#     k        inertia
# 0   1  287556.781250
# 1   2  170766.015625
# 2   3  131367.093750
# 3   4   99289.828125
# 4   5   73328.937500
# 5   6   61224.988281
# 6   7   51676.523438
# 7   8   42745.878906
# 8   9   36369.003906
# 9  10   32871.390625

# %%
plt.plot(elbow_df['k'], elbow_df['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
model = KMeans(n_clusters=5)
model.fit(tsne_features)
predictions = model.predict(tsne_features)
predictions
# Out:
# array([2, 2, 0, 2, 0, 3, 3, 3, 0, 3, 1, 3, 3, 3, 2, 0, 0, 2, 2, 2, 3, 3,
#        2, 2, 2, 2, 0, 3, 3, 3, 0, 0, 3, 2, 2, 3, 3, 3, 3, 0, 3, 2, 0, 2,
#        3, 2, 3, 3, 3, 0, 2, 3, 3, 2, 2, 0, 3, 2, 3, 0, 2, 2, 2, 2, 0, 3,
#        2, 3, 0, 3, 0, 2, 2, 2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2, 2, 2,
#        2, 2, 2, 3, 2, 0, 3, 2, 0, 2, 2, 2, 2, 0, 3, 2, 3, 3, 2, 3, 0, 3,
#        0, 2, 2, 2, 2, 2, 0, 3, 3, 3, 0, 2, 2, 3, 2, 2, 0, 2, 0, 2, 2, 1,
#        2, 0, 2, 2, 2, 0, 0, 3, 2, 4, 2, 2, 2, 0, 2, 3, 2, 3, 0, 2, 3, 3,
#        2, 3, 0, 3, 3, 0, 2, 2, 2, 0, 0, 2, 0, 2, 2, 0, 3, 3, 2, 3, 2, 2,
#        0, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 3, 2, 0, 2, 2, 4, 0, 3, 0, 2, 0,
#        3, 0, 0, 3, 0, 3, 0, 3, 2, 0, 2, 0, 0, 0, 0, 2, 3, 0, 0, 3, 0, 0,
#        0, 2, 2, 3, 2, 3, 2, 3, 2, 0, 3, 3, 2, 2, 0, 2, 0, 0, 2, 2, 3, 3,
#        2, 3, 0, 2, 3, 2, 0, 2, 2, 2, 2, 1, 2, 2, 0, 2, 0, 0, 0, 2, 2, 2,
#        2, 2, 3, 3, 2, 0, 3, 4, 2, 2, 2, 3, 0, 4, 3, 0, 3, 2, 2, 0, 2, 3,
# ...

# %%
crypto_df["class"] = model.labels_
crypto_df
# Out:
#        Algorithm ProofType  TotalCoinsMined TotalCoinSupply  class
# 0         Scrypt   PoW/PoS     4.199995e+01              42      2
# 1         Scrypt   PoW/PoS     1.055185e+09       532000000      2
# 2            X13   PoW/PoS     2.927942e+10    314159265359      0
# 3        SHA-256       PoW     1.792718e+07        21000000      2
# 4         Ethash       PoW     1.076842e+08               0      0
# ..           ...       ...              ...             ...    ...
# 527      SHA-256      DPoS     2.000000e+09      2000000000      3
# 528       Scrypt   PoW/PoS     1.493105e+07       250000000      2
# 529  CryptoNight       PoW     9.802226e+08      1400222610      2
# 530     Equihash       PoW     7.296538e+06        21000000      3
# 531       Scrypt       PoS     1.283270e+05         1000000      0
#
# [532 rows x 5 columns]

# %% [markdown]
# # Recomendations
# It appears that the crypto currencies can be clustered into groups. I took looks like the best choices would be 2 or 5 groups. I personally consider 5 groups the best choice.
